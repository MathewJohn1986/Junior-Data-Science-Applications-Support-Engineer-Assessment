# %% [markdown]
# # Junior Data Science Applications Support Engineer Assessment

# %% [markdown]
# Created by Mathew John van Wyk

# %% [markdown]
# # Question 1
#
# # Write a function, foo(L), that returns the smallest positive integer (1 or larger) that does not occur in the list L.

# %% [markdown]
# # What is foo in software programming

# %% [markdown]
# Foo (pronounced FOO) is a term used by programmers as a placeholder for a value that can change, depending on conditions or on information passed to the program. Foo and other words like it are formally known as metasyntactic variables.

# %% [markdown]
# # How foo works in programming

# %% [markdown]
# It can be helpful to use metasyntactic variables when creating sample code because programmers don't have to create unique names for each variable value. Nonsense placeholders make it easier to focus on the code's core concept and functional goal.

# %% [markdown]
# # Python Module

# %% [markdown]
# the foo() function

# %%
def foo(L):
    sorted_L = sorted(L) # the first element is the smallest integer (assumption is that the list is sorted from smallest to the biggest integer)
    if sorted_L[0] == 0:
        return 'No smallest positive integer'
    else:
        smallest_integer = sorted_L[0]-1 # obtaining an integer outside of the list
        return smallest_integer

# %%
foo([10,7,15,11,9])
# Out:
# 6

# %% [markdown]
# # Question 2
#
# # In this task, you must write a command-line program that outputs to stdout the name of the country in which a set of coordinates is located. The program should take 2 positional command-line arguments, the latitude component, followed by the longitude component. The program may connect to the internet. For example: python3 question2.py -26.2022700 28.0436300 Should output “South Africa” to the terminal.

# %% [markdown]
# # Installation

# %% [markdown]
# # What is geopy

# %% [markdown]
# geopy is a Python client for several popular geocoding web services. geopy makes it easy for Python developers to locate the coordinates of addresses, cities, countries, and landmarks across the globe using third-party geocoders and other data sources.

# %% [markdown]
# # What is pprint

# %% [markdown]
# The pprint module provides a capability to “pretty-print” arbitrary Python data structures in a form which can be used as input to the interpreter. If the formatted structures include objects which are not fundamental Python types, the representation may not be loadable.

# %% [markdown]
# # What is Nominatim

# %% [markdown]
# Nominatim is the Latin for ('by name'). It is also a tool to search OpenStreetMap data by address or location (geocoding). Nominatim is included in the GeoPy in the GeoPy Python library.

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import Nominatim
import time
from pprint import pprint

# %% [markdown]
# initialize Nominatim API

# %%
geolocator = Nominatim(user_agent="geoapiExercises")

# %% [markdown]
# # Python Module

# %%
# Latitude & Longitude input


Latitude = "-33.884010"
Longitude = "18.494630"

location = geolocator.reverse(Latitude+","+Longitude)

# Display


print(location)
# Out:
# Kildare Road, Woodbridge Island, Cape Town Ward 55, Milnerton, City of Cape Town, Western Cape, 2251, South Africa

# %% [markdown]
# # Question 3
#
# # Find the characters in the string X, below that are not one of the elements of the list['1','2','3','4','5']. Join them into a string and write out the resulting string.

# %% [markdown]
# # Python Module

# %% [markdown]
# A character string is a series of characters manipulated as a group.
# A character string differs from a name in that it does not represent anything — a name stands for some other object.
# A character string is often specified by enclosing the characters in single or double quotes.

# %% [markdown]
# # What is isalpha

# %% [markdown]
# Python String isalpha() method is a built-in method used for string handling. The isalpha() methods returns “True” if all characters in the string are alphabets, Otherwise, It returns “False”. This function is used to check if the argument includes only alphabet characters

# %%
def isalpha(c):
    
    """ Check if a character is a member of the alphabet """
    
    return c.isalpha()

s = "..."
f = filter(isalpha, s)
''.join(f)
# Out:
# 'SS'

# %% [markdown]
# # Question 4
#
# # Download the entire text of Frankenstein from https://www.gutenberg.org/cache/epub/42324/pg42324.txt. Write code to compute how many vowels are there in this entire file (not just the main body of the book)?

# %% [markdown]
# # Installation

# %% [markdown]
# The OS module in Python provides functions for creating and removing a directory (folder),
# fetching its contents, changing and identifying the current directory, etc.
#
# You first need to import the os module to interact with the underlying operating system.

# %%
import os

# %% [markdown]
# # Python Module

# %% [markdown]
# open file in read mode

# %%
file = open("The_Project_Gutenberg_EBook_of_Frankenstein.txt","r")

# read all the contents of file
# and store in a string variable 
# named string using read() function

string = file.read()


# find the number of the vowels in file


vowel_count =  0
for i in string:
    if( i=='A' or i=='a' or i=='E' or i=='e' or i=='I'
        or i=='i' or i=='O' or i=='o'
	or i=='U' or i=='u'):
        	vowel_count +=1
        

print('The Number of Vowels in text file :', vowel_count)
# Out:
# The Number of Vowels in text file : 138040

# %% [markdown]
# # Question 5
#
# # What text is encoded in the image? (Hint: load the image, look at the pixel values and think creatively!)

# %% [markdown]
# ![Picture2.png](attachment:Picture2.png)

# %% [markdown]
# # What is PIL

# %% [markdown]
# Python Imaging Library is a free and open-source additional library for the Python programming language that adds support for opening, manipulating, and saving many different image file formats.

# %% [markdown]
# # Installation

# %%
from PIL import Image

# %% [markdown]
# We use a function of Image module called getdata() to extract the pixel values.
# This scans the image horizontally from left to right starting at the top-left corner.
# The values got from each pixel is then added into a list

# %%
img = Image.open("Picture2.png", "r")

# %% [markdown]
# This list comprehension extracts each element of each set in the
#                   list pix_val and all the elements are stored in pix_val_flat.
# Thus this can be compiled into a script or made into a function which can be used in any image processing projects later

# %%
pix_val = list(img.getdata())

# %% [markdown]
# obtaining the pixel value for each line in image

# %%
pix_val
# Out:
# [(44, 47, 23, 255),
#  (43, 47, 22, 255),
#  (41, 44, 19, 255),
#  (35, 39, 14, 255),
#  (35, 40, 14, 255),
#  (38, 41, 17, 255),
#  (40, 44, 20, 255),
#  (40, 43, 18, 255),
#  (42, 46, 18, 255),
#  (46, 52, 22, 255),
#  (54, 61, 28, 255),
#  (61, 70, 36, 255),
#  (68, 78, 41, 255),
#  (73, 85, 45, 255),
#  (76, 91, 46, 255),
#  (78, 95, 45, 255),
#  (79, 98, 46, 255),
#  (80, 100, 45, 255),
#  (79, 100, 43, 255),
#  (77, 100, 40, 255),
#  (77, 102, 37, 255),
#  (79, 104, 38, 255),
#  (79, 105, 35, 255),
#  (79, 105, 31, 255),
#  (78, 104, 30, 255),
#  (77, 104, 28, 255),
#  (77, 104, 27, 255),
#  (77, 105, 27, 255),
#  (76, 105, 26, 255),
#  (75, 104, 23, 255),
#  (71, 102, 19, 255),
#  (70, 101, 18, 255),
#  (69, 101, 16, 255),
#  (70, 101, 16, 255),
#  (71, 103, 18, 255),
#  (72, 104, 19, 255),
#  (72, 105, 18, 255),
#  (72, 105, 17, 255),
#  (73, 105, 18, 255),
#  (74, 104, 18, 255),
#  (74, 103, 18, 255),
#  (75, 104, 19, 255),
#  (77, 105, 21, 255),
#  (78, 107, 22, 255),
# ...

# %% [markdown]
# # What Is Steganography

# %% [markdown]
# Steganography is the practice of hiding a secret message inside of (or even on top of) something that is not secret. That something can be just about anything you want. These days, many examples of steganography involve embedding a secret piece of text inside of a picture. Or hiding a secret message or script inside of a Word or Excel document.

# %% [markdown]
# # What is LSB-Steganography

# %% [markdown]
# Python program based on stegonographical methods to hide files in images using the Least Significant Bit technique.
#
# I used the most basic method which is the least significant bit. A colour pixel is composed of red, green and blue, encoded on one byte. The idea is to store information in the first bit of every pixel's RGB component. In the worst case, the decimal value is different by one which is not visible to the human eye. In practice, if you don't have space to store all of your data in the first bit of every pixel you should start using the second bit, and so on. You have to keep in mind that the more your store data in an image, the more it can be detected.

# %% [markdown]
# # Installation

# %% [markdown]
# This tool only require OpenCV and its dependencies.

# %%
pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Python module

# %% [markdown]
# Text encoding:

# %%
from LSBSteg import *

#encoding

steg = LSBSteg(cv2.imread("Picture2.png"))
img_encoded = steg.encode_text("there is a hidden message in the image")
cv2.imwrite("my_new_image.png", img_encoded)
# Out:
# True

# %%
from LSBSteg import *

#decoding

im = cv2.imread("my_new_image.png")
steg = LSBSteg(im)
print("Text value:",steg.decode_text())
# Out:
# Text value: there is a hidden message in the image

# %% [markdown]
# # Question 6
#
# # Given a Pandas dataframe, df1, with a column Freq that contains float values between 1000 and 2000. What will the following piece of code do?

# %% [markdown]
# # Installation

# %%
import pandas as pd

# %% [markdown]
# # Python Module

# %%
def range_func(df):
    if 1567.7 <= df['Freq'] <= 1582.7:
        return 'L1'
    elif 1222.1 <= df['Freq'] <= 1232.1:
        return 'L2'
    elif 1375.9 <= df['Freq'] <= 1385.9:
        return 'L3'
    elif 1374.8 <= df['Freq'] <= 1384.8:
        return 'L4'
    elif 1170.2 <= df['Freq'] <= 1182.2:
        
df1['type'] = df1.apply (lambda x: range_func(x), axis=1)
# Out:
#   File "C:\Users\Mathew\AppData\Local\Temp/ipykernel_6156/1002703576.py", line 12
#     df1['type'] = df1.apply (lambda x: range_func(x), axis=1)
#                                                                     ^
# IndentationError: expected an indented block

# %% [markdown]
# # Question 7
#
# # Which regular expression in python can be used to determine if a password adheres to the following rules: "6 to 12 characters in length. Must have at least one uppercase letter. Must have at least one lower case letter. Must have at least one digit"

# %%
^(?=.*[a-z])(?=.*[A-Z])(?=.*\d).{6,12}$
